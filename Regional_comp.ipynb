# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Предобработка количественных данных

# %% [markdown]
# ### Компетенция чемпионата по русскому языку

# %%
df = pd.read_csv("2022_Russian_data.csv")

# %%
df.head(10).T
# Out:
#                                  0             1                 2  \
# SUBJECT               русский язык  русский язык      русский язык
# YEAR                          2022          2022              2022
# REGION                      Адыгея        Адыгея            Адыгея
# DATA_AVAILABLE                TRUE          TRUE              TRUE
# WINNERS_ONLY                 False         False             False
# GRADE_OF_COMPETITION           9.0           9.0               9.0
# ID                             1.0           2.0               3.0
# CODE                           NaN           NaN               NaN
# DISTRICT              Город Майкоп      ГБОУ АРГ  Майкопский район
# SCHOOL                         NaN           NaN               NaN
# T1                             1.5           0.5               3.0
# T2                             0.0           0.0               0.0
# T3                             0.0           0.0               0.0
# T4                             4.5           3.0               0.0
# T5                             7.5           1.0               1.0
# T6                             2.0           1.0               0.0
# T7                             9.0           2.0               1.0
# T8                             NaN           NaN               NaN
# SUM                           24.5           7.5               5.0
# PERCENTAGE                    27.8           8.5               5.7
# REGIONAL_STATUS                NaN           NaN               NaN
# AUTHENTIC                      оба           оба               оба
# FINAL_SUM                      NaN           NaN               NaN
# FINAL_PERCENTAGE               NaN           NaN               NaN
# FINAL_STATUS                   NaN           NaN               NaN
# COMMENT                        NaN           NaN               NaN
#
#                                          3                 4  \
# SUBJECT                       русский язык      русский язык
# YEAR                                  2022              2022
# REGION                              Адыгея            Адыгея
# DATA_AVAILABLE                        TRUE              TRUE
# WINNERS_ONLY                         False             False
# GRADE_OF_COMPETITION                   9.0               9.0
# ID                                     4.0               5.0
# CODE                                   NaN               NaN
# DISTRICT              Тахтамукайский район  Майкопский район
# SCHOOL                                 NaN               NaN
# T1                                     2.5               1.0
# T2                                     0.0               0.0
# T3                                     0.0               0.0
# T4                                     1.5               3.0
# T5                                     0.5               0.0
# T6                                     0.0               0.0
# T7                                     0.0               0.0
# T8                                     NaN               NaN
# SUM                                    4.5               4.0
# PERCENTAGE                             5.1               4.5
# REGIONAL_STATUS                        NaN               NaN
# AUTHENTIC                              оба               оба
# FINAL_SUM                              NaN               NaN
# FINAL_PERCENTAGE                       NaN               NaN
# FINAL_STATUS                           NaN               NaN
# COMMENT                                NaN               NaN
#
#                                      5                     6  \
# SUBJECT                   русский язык          русский язык
# YEAR                              2022                  2022
# REGION                          Адыгея                Адыгея
# DATA_AVAILABLE                    TRUE                  TRUE
# WINNERS_ONLY                     False                 False
# GRADE_OF_COMPETITION               9.0                   9.0
# ID                                 6.0                   7.0
# CODE                               NaN                   NaN
# DISTRICT              Теучежский район  Тахтамукайский район
# SCHOOL                             NaN                   NaN
# T1                                 1.0                   0.0
# T2                                 0.0                   0.0
# T3                                 0.0                   0.0
# T4                                 3.0                   3.0
# T5                                 0.0                   0.5
# T6                                 0.0                   0.5
# T7                                 0.0                   0.0
# T8                                 NaN                   NaN
# SUM                                4.0                   3.5
# PERCENTAGE                         4.5                   4.0
# REGIONAL_STATUS                    NaN                   NaN
# AUTHENTIC                          оба                   оба
# FINAL_SUM                          NaN                   NaN
# FINAL_PERCENTAGE                   NaN                   NaN
# FINAL_STATUS                       NaN                   NaN
# COMMENT                            NaN                   NaN
#
#                                      7                 8                 9
# SUBJECT                   русский язык      русский язык      русский язык
# YEAR                              2022              2022              2022
# REGION                          Адыгея            Адыгея            Адыгея
# DATA_AVAILABLE                    TRUE              TRUE              TRUE
# WINNERS_ONLY                     False             False             False
# GRADE_OF_COMPETITION               9.0               9.0               9.0
# ID                                 8.0               9.0              10.0
# CODE                               NaN               NaN               NaN
# DISTRICT              Майкопский район  Майкопский район  Теучежский район
# SCHOOL                             NaN               NaN               NaN
# T1                                 0.0               1.5               0.0
# T2                                 0.0               0.0               0.0
# T3                                 0.0               0.5               0.0
# T4                                 3.5               0.5               0.5
# T5                                 0.0               0.0               0.5
# T6                                 0.0               0.0               1.5
# T7                                 0.0               0.0               0.0
# T8                                 NaN               NaN               NaN
# SUM                                3.5               2.5               2.5
# PERCENTAGE                         4.0               2.8               2.8
# REGIONAL_STATUS                    NaN               NaN               NaN
# AUTHENTIC                          оба               оба               оба
# FINAL_SUM                          NaN               NaN               NaN
# FINAL_PERCENTAGE                   NaN               NaN               NaN
# FINAL_STATUS                       NaN               NaN               NaN
# COMMENT                            NaN               NaN               NaN

# %% [markdown]
# # Описание признаков
# * SUBJECT: школьный предмет
# * YEAR: год состязания
# * REGION: регион России (включая аннексированные Республику Крым и Севастополь)
# * DATA_AVAILABLE: имеются ли данные для региона. Данные считались имеющимися, если хотя бы для победителей и призёров регионального этапа известны результаты в баллах или в процентах от теоретического максимума, а не только статусы победителя, призёра и т. п.
# * WINNERS_ONLY: представлены ли данные только для участников, получивших дипломы, или для всех участников регионального этапа в данном регионе. NB: для Свердловской области данные в принятом нами смысле имеются только для победителей, однако призёры включены в датасет; выбрано значение TRUE
# * GRADE_OF_COMPETITION: класс, задания для которого выполнял участник (9, 10 или 11)
# * ID: уникальный идентификатор участника (выбран произвольно)
# * CODE: шифр участника на региональном этапе
# * DISTRICT: район, город, муниципальное образование и т. д., к которому относится школа участника
# * SCHOOL: школа, за которую выступает участник
# * T1–T8: оценки участника в баллах за задания 1–8 регионального этапа. Несравнимы между классами!
# * SUM: сумма баллов участника за все задания регионального этапа. Теоретическая максимально возможная сумма в 2021 году для 9 класса составляла 90 баллов, для 10 класса — 100 баллов, для 11 класса — 110 баллов; в 2022 году для 9 класса — 88 баллов, для 10 класса — 100 баллов, для 11 класса — 112 баллов
# * PERCENTAGE: процент, который сумма баллов участника на региональном этапе составляет от теоретического максимума
# * REGIONAL_STATUS: категория, к которой участник отнесён по итогам регионального этапа. Основными являются Победитель, Призер, Участник, а также пустая категория, по смыслу совпадающая со статусом Участника. Отнесение следует различным правилам в разных регионах, поэтому в общем случае статусы плохо сравнимы между регионами (для отбора на заключительный этап используются не они, а единый для страны проходной балл)
# * AUTHENTIC: какое из значений полей SUM и PERCENTAGE представлено в исходных данных, а какое вычислено при создании датасета. В случаях, когда исходным был процент выполнения (и тем более отсутствовали результаты проверки отдельных заданий), суммы несистематически приводились к разрешённому правилами шагу в 0,5 балла
# * FINAL_SUM: сумма баллов участника на заключительном этапе. Теоретическая максимально возможная сумма в 2021 году для 9 класса составляла 150 баллов, для 10 класса — 165 баллов, для 11 класса — 180 баллов
# * FINAL_PERCENTAGE: процент, который сумма баллов участника на заключительном этапе составляет от теоретического максимума
# * FINAL_STATUS: категория, к которой участник отнесён по итогам заключительного этапа. Возможные значения: Победитель, Призер, Участник
# * COMMENT: неформальный комментарий

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12514 entries, 0 to 12513
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SUBJECT               12514 non-null  object
#  1   YEAR                  12514 non-null  int64
#  2   REGION                12514 non-null  object
#  3   DATA_AVAILABLE        12514 non-null  object
#  4   WINNERS_ONLY          12507 non-null  object
#  5   GRADE_OF_COMPETITION  12507 non-null  float64
#  6   ID                    12508 non-null  float64
#  7   CODE                  2941 non-null   object
#  8   DISTRICT              4658 non-null   object
#  9   SCHOOL                2552 non-null   object
#  10  T1                    3414 non-null   float64
#  11  T2                    3414 non-null   float64
#  12  T3                    3414 non-null   float64
#  13  T4                    3414 non-null   float64
#  14  T5                    3414 non-null   float64
#  15  T6                    3414 non-null   float64
#  16  T7                    3413 non-null   float64
#  17  T8                    0 non-null      float64
#  18  SUM                   7462 non-null   float64
#  19  PERCENTAGE            12468 non-null  float64
#  20  REGIONAL_STATUS       10589 non-null  object
#  21  AUTHENTIC             12508 non-null  object
#  22  FINAL_SUM             0 non-null      float64
#  23  FINAL_PERCENTAGE      0 non-null      float64
#  24  FINAL_STATUS          0 non-null      float64
#  25  COMMENT               7 non-null      object
# dtypes: float64(15), int64(1), object(10)
# memory usage: 2.5+ MB

# %% [markdown]
# Так как мы видим что значени FINAL_SUM, FINAL_PERCANTEGE и FINAL_STATUS пустые,и никакой формулы для них нету, мы можем их удалить, ведь итоговая сумма уже подсчитана в SUM PERCENTAGE и STATUS

# %%
df.drop("FINAL_SUM", axis=1, inplace=True)
df.drop("FINAL_PERCENTAGE", axis=1, inplace=True)
df.drop("FINAL_STATUS", axis=1, inplace=True)
df.reset_index()
# Out:
#        index       SUBJECT  YEAR               REGION DATA_AVAILABLE  \
# 0          0  русский язык  2022               Адыгея           TRUE
# 1          1  русский язык  2022               Адыгея           TRUE
# 2          2  русский язык  2022               Адыгея           TRUE
# 3          3  русский язык  2022               Адыгея           TRUE
# 4          4  русский язык  2022               Адыгея           TRUE
# ...      ...           ...   ...                  ...            ...
# 12509  12509  русский язык  2022  Ярославская область           TRUE
# 12510  12510  русский язык  2022  Ярославская область           TRUE
# 12511  12511  русский язык  2022  Ярославская область           TRUE
# 12512  12512  русский язык  2022  Ярославская область           TRUE
# 12513  12513  русский язык  2022              Чувашия          FALSE
#
#       WINNERS_ONLY  GRADE_OF_COMPETITION       ID CODE              DISTRICT  \
# 0            False                   9.0      1.0  NaN          Город Майкоп
# 1            False                   9.0      2.0  NaN              ГБОУ АРГ
# 2            False                   9.0      3.0  NaN      Майкопский район
# 3            False                   9.0      4.0  NaN  Тахтамукайский район
# 4            False                   9.0      5.0  NaN      Майкопский район
# ...            ...                   ...      ...  ...                   ...
# 12509        False                  11.0  12505.0  NaN          Любимский МР
# 12510        False                  11.0  12506.0  NaN         Ростовский МР
# 12511        False                  11.0  12507.0  NaN         Ростовский МР
# 12512        False                  11.0  12508.0  NaN          г. Ярославль
# 12513          NaN                   NaN      NaN  NaN                   NaN
#
#        ...   T4   T5   T6   T7  T8   SUM  PERCENTAGE  REGIONAL_STATUS  \
# 0      ...  4.5  7.5  2.0  9.0 NaN  24.5        27.8              NaN
# 1      ...  3.0  1.0  1.0  2.0 NaN   7.5         8.5              NaN
# 2      ...  0.0  1.0  0.0  1.0 NaN   5.0         5.7              NaN
# 3      ...  1.5  0.5  0.0  0.0 NaN   4.5         5.1              NaN
# 4      ...  3.0  0.0  0.0  0.0 NaN   4.0         4.5              NaN
# ...    ...  ...  ...  ...  ...  ..   ...         ...              ...
# 12509  ...  0.5  1.5  2.5  0.0 NaN   4.5         4.0              NaN
# 12510  ...  0.5  1.0  1.0  0.0 NaN   4.5         4.0              NaN
# 12511  ...  0.0  1.5  0.0  0.0 NaN   3.0         2.7              NaN
# 12512  ...  0.0  0.0  2.0  0.0 NaN   2.0         1.8              NaN
# 12513  ...  NaN  NaN  NaN  NaN NaN   NaN         NaN              NaN
#
#        AUTHENTIC  COMMENT
# 0            оба      NaN
# 1            оба      NaN
# 2            оба      NaN
# 3            оба      NaN
# 4            оба      NaN
# ...          ...      ...
# 12509        оба      NaN
# 12510        оба      NaN
# 12511        оба      NaN
# 12512        оба      NaN
# 12513        NaN      NaN
#
# [12514 rows x 24 columns]

# %%
df["REGIONAL_STATUS"].fillna("Участник", inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14828\1323918455.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["REGIONAL_STATUS"].fillna("Участник", inplace=True)

# %% [markdown]
# Несмотря то что нам выдает Exception, метод успешно отработал и заменил пустые значения на соответсвутющие

# %%
df.REGIONAL_STATUS.sample(20)
# Out:
# 4169       Призер
# 3079       Призер
# 1999     Участник
# 10792    Участник
# 101      Участник
# 4783     Участник
# 12071    Участник
# 10608    Участник
# 10060    Участник
# 3486     Участник
# 9514     Участник
# 11404    Участник
# 4847     Участник
# 6799       Призер
# 1369     Участник
# 4368     Участник
# 5740       Призер
# 11094    Участник
# 2924     Участник
# 10557    Участник
# Name: REGIONAL_STATUS, dtype: object

# %%
df.describe()
# Out:
#           YEAR  GRADE_OF_COMPETITION            ID           T1           T2  \
# count  12514.0          12507.000000  12508.000000  3414.000000  3414.000000
# mean    2022.0             10.051651   6254.500000     2.344757     0.352665
# std        0.0              1.097466   3610.892918     2.254255     1.828766
# min     2022.0              8.000000      1.000000     0.000000     0.000000
# 25%     2022.0              9.000000   3127.750000     1.000000     0.000000
# 50%     2022.0             10.000000   6254.500000     2.000000     0.000000
# 75%     2022.0             11.000000   9381.250000     3.000000     0.000000
# max     2022.0             37.000000  12508.000000    17.500000    15.000000
#
#                 T3           T4           T5          T6           T7   T8  \
# count  3414.000000  3414.000000  3414.000000  3414.00000  3413.000000  0.0
# mean      0.503808     2.156415     2.339045     1.83802     2.103575  NaN
# std       1.371773     2.197838     1.831161     2.48997     2.429675  NaN
# min       0.000000     0.000000     0.000000     0.00000     0.000000  NaN
# 25%       0.000000     0.000000     1.000000     0.00000     0.000000  NaN
# 50%       0.000000     1.500000     2.000000     1.00000     1.000000  NaN
# 75%       0.000000     4.000000     3.500000     3.00000     3.000000  NaN
# max      10.000000    10.000000    12.000000    17.00000    12.000000  NaN
#
#                SUM    PERCENTAGE
# count  7462.000000  12468.000000
# mean     14.411521     13.962167
# std      13.817028     12.252670
# min       0.000000      0.000000
# 25%       4.500000      5.113636
# 50%      10.000000     10.700000
# 75%      19.000000     18.750000
# max      84.000000     86.930000

# %% [markdown]
# Мы видим аномальное значение, то что есть записи с людьми которые учились в 37 классе, по описанию мы знаем что максимально допустимый лимит 11 классов, соответственно мы удаляем аномальное значение

# %%
df = df[df["GRADE_OF_COMPETITION"] <= 11]

# %%
df[df["GRADE_OF_COMPETITION"] > 11]
# Out:
# Empty DataFrame
# Columns: [SUBJECT, YEAR, REGION, DATA_AVAILABLE, WINNERS_ONLY, GRADE_OF_COMPETITION, ID, CODE, DISTRICT, SCHOOL, T1, T2, T3, T4, T5, T6, T7, T8, SUM, PERCENTAGE, REGIONAL_STATUS, AUTHENTIC, COMMENT]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.reset_index()
# Out:
#        index       SUBJECT  YEAR               REGION DATA_AVAILABLE  \
# 0          0  русский язык  2022               Адыгея           TRUE
# 1          1  русский язык  2022               Адыгея           TRUE
# 2          2  русский язык  2022               Адыгея           TRUE
# 3          3  русский язык  2022               Адыгея           TRUE
# 4          4  русский язык  2022               Адыгея           TRUE
# ...      ...           ...   ...                  ...            ...
# 12476  12508  русский язык  2022  Ярославская область           TRUE
# 12477  12509  русский язык  2022  Ярославская область           TRUE
# 12478  12510  русский язык  2022  Ярославская область           TRUE
# 12479  12511  русский язык  2022  Ярославская область           TRUE
# 12480  12512  русский язык  2022  Ярославская область           TRUE
#
#       WINNERS_ONLY  GRADE_OF_COMPETITION       ID CODE              DISTRICT  \
# 0            False                   9.0      1.0  NaN          Город Майкоп
# 1            False                   9.0      2.0  NaN              ГБОУ АРГ
# 2            False                   9.0      3.0  NaN      Майкопский район
# 3            False                   9.0      4.0  NaN  Тахтамукайский район
# 4            False                   9.0      5.0  NaN      Майкопский район
# ...            ...                   ...      ...  ...                   ...
# 12476        False                  11.0  12504.0  NaN          г. Ярославль
# 12477        False                  11.0  12505.0  NaN          Любимский МР
# 12478        False                  11.0  12506.0  NaN         Ростовский МР
# 12479        False                  11.0  12507.0  NaN         Ростовский МР
# 12480        False                  11.0  12508.0  NaN          г. Ярославль
#
#        ...   T4   T5   T6   T7  T8   SUM  PERCENTAGE  REGIONAL_STATUS  \
# 0      ...  4.5  7.5  2.0  9.0 NaN  24.5        27.8         Участник
# 1      ...  3.0  1.0  1.0  2.0 NaN   7.5         8.5         Участник
# 2      ...  0.0  1.0  0.0  1.0 NaN   5.0         5.7         Участник
# 3      ...  1.5  0.5  0.0  0.0 NaN   4.5         5.1         Участник
# 4      ...  3.0  0.0  0.0  0.0 NaN   4.0         4.5         Участник
# ...    ...  ...  ...  ...  ...  ..   ...         ...              ...
# 12476  ...  0.5  3.5  0.0  0.0 NaN   5.5         4.9         Участник
# 12477  ...  0.5  1.5  2.5  0.0 NaN   4.5         4.0         Участник
# 12478  ...  0.5  1.0  1.0  0.0 NaN   4.5         4.0         Участник
# 12479  ...  0.0  1.5  0.0  0.0 NaN   3.0         2.7         Участник
# 12480  ...  0.0  0.0  2.0  0.0 NaN   2.0         1.8         Участник
#
#        AUTHENTIC  COMMENT
# 0            оба      NaN
# 1            оба      NaN
# 2            оба      NaN
# 3            оба      NaN
# 4            оба      NaN
# ...          ...      ...
# 12476        оба      NaN
# 12477        оба      NaN
# 12478        оба      NaN
# 12479        оба      NaN
# 12480        оба      NaN
#
# [12481 rows x 24 columns]

# %% [markdown]
# ### Видимо что значений выше 11 класса не осталось, значит мы сделали все правильно

# %%
df.shape
# Out:
# (12481, 23)

# %%
df["CODE"].notna().value_counts()
# Out:
# CODE
# False    9540
# True     2941
# Name: count, dtype: int64

# %%
df["COMMENT"].notna().value_counts()
# Out:
# COMMENT
# False    12474
# True         7
# Name: count, dtype: int64

# %% [markdown]
# ### Мы видим значения комментариев и Code не пустое, значит мы можем его оставить

# %%
df[df["SUM"] >= 88]
# Out:
# Empty DataFrame
# Columns: [SUBJECT, YEAR, REGION, DATA_AVAILABLE, WINNERS_ONLY, GRADE_OF_COMPETITION, ID, CODE, DISTRICT, SCHOOL, T1, T2, T3, T4, T5, T6, T7, T8, SUM, PERCENTAGE, REGIONAL_STATUS, AUTHENTIC, COMMENT]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ### Видим что аномальных значений в SUM не найденно, так как ни 1 из них не превышает максимума

# %%
df.T8.notna().value_counts()
# Out:
# T8
# False    12481
# Name: count, dtype: int64

# %% [markdown]
# ### Мы видим что Т8 этап не проводился, поэтому смело можем его убрать

# %%
df.drop("T8", axis=1, inplace=True)
df.reset_index()
# Out:
#        index       SUBJECT  YEAR               REGION DATA_AVAILABLE  \
# 0          0  русский язык  2022               Адыгея           TRUE
# 1          1  русский язык  2022               Адыгея           TRUE
# 2          2  русский язык  2022               Адыгея           TRUE
# 3          3  русский язык  2022               Адыгея           TRUE
# 4          4  русский язык  2022               Адыгея           TRUE
# ...      ...           ...   ...                  ...            ...
# 12476  12508  русский язык  2022  Ярославская область           TRUE
# 12477  12509  русский язык  2022  Ярославская область           TRUE
# 12478  12510  русский язык  2022  Ярославская область           TRUE
# 12479  12511  русский язык  2022  Ярославская область           TRUE
# 12480  12512  русский язык  2022  Ярославская область           TRUE
#
#       WINNERS_ONLY  GRADE_OF_COMPETITION       ID CODE              DISTRICT  \
# 0            False                   9.0      1.0  NaN          Город Майкоп
# 1            False                   9.0      2.0  NaN              ГБОУ АРГ
# 2            False                   9.0      3.0  NaN      Майкопский район
# 3            False                   9.0      4.0  NaN  Тахтамукайский район
# 4            False                   9.0      5.0  NaN      Майкопский район
# ...            ...                   ...      ...  ...                   ...
# 12476        False                  11.0  12504.0  NaN          г. Ярославль
# 12477        False                  11.0  12505.0  NaN          Любимский МР
# 12478        False                  11.0  12506.0  NaN         Ростовский МР
# 12479        False                  11.0  12507.0  NaN         Ростовский МР
# 12480        False                  11.0  12508.0  NaN          г. Ярославль
#
#        ...   T3   T4   T5   T6   T7   SUM  PERCENTAGE  REGIONAL_STATUS  \
# 0      ...  0.0  4.5  7.5  2.0  9.0  24.5        27.8         Участник
# 1      ...  0.0  3.0  1.0  1.0  2.0   7.5         8.5         Участник
# 2      ...  0.0  0.0  1.0  0.0  1.0   5.0         5.7         Участник
# 3      ...  0.0  1.5  0.5  0.0  0.0   4.5         5.1         Участник
# 4      ...  0.0  3.0  0.0  0.0  0.0   4.0         4.5         Участник
# ...    ...  ...  ...  ...  ...  ...   ...         ...              ...
# 12476  ...  0.0  0.5  3.5  0.0  0.0   5.5         4.9         Участник
# 12477  ...  0.0  0.5  1.5  2.5  0.0   4.5         4.0         Участник
# 12478  ...  0.0  0.5  1.0  1.0  0.0   4.5         4.0         Участник
# 12479  ...  0.0  0.0  1.5  0.0  0.0   3.0         2.7         Участник
# 12480  ...  0.0  0.0  0.0  2.0  0.0   2.0         1.8         Участник
#
#        AUTHENTIC  COMMENT
# 0            оба      NaN
# 1            оба      NaN
# 2            оба      NaN
# 3            оба      NaN
# 4            оба      NaN
# ...          ...      ...
# 12476        оба      NaN
# 12477        оба      NaN
# 12478        оба      NaN
# 12479        оба      NaN
# 12480        оба      NaN
#
# [12481 rows x 23 columns]

# %%
df.sample(20).T
# Out:
#                                    5720               9467          3082   \
# SUBJECT                     русский язык       русский язык  русский язык
# YEAR                                2022               2022          2022
# REGION                Московская область  Самарская область        Москва
# DATA_AVAILABLE                      TRUE               TRUE          TRUE
# WINNERS_ONLY                       False              False         False
# GRADE_OF_COMPETITION                10.0                9.0          10.0
# ID                                5719.0             9465.0        3081.0
# CODE                                 NaN                NaN      28238908
# DISTRICT                             NaN        г. Тольятти           NaN
# SCHOOL                               NaN                NaN           NaN
# T1                                   NaN                NaN           NaN
# T2                                   NaN                NaN           NaN
# T3                                   NaN                NaN           NaN
# T4                                   NaN                NaN           NaN
# T5                                   NaN                NaN           NaN
# T6                                   NaN                NaN           NaN
# T7                                   NaN                NaN           NaN
# SUM                                  NaN                NaN          47.0
# PERCENTAGE                          16.5                3.4          47.0
# REGIONAL_STATUS                   Призер           Участник        Призер
# AUTHENTIC                        процент            процент           оба
# COMMENT                              NaN                NaN           NaN
#
#                              3426                   702                 5124   \
# SUBJECT               русский язык           русский язык        русский язык
# YEAR                          2022                   2022                2022
# REGION                      Москва  Волгоградская область  Московская область
# DATA_AVAILABLE                TRUE                   TRUE                TRUE
# WINNERS_ONLY                 False                  False               False
# GRADE_OF_COMPETITION          10.0                   10.0                 9.0
# ID                          3425.0                  701.0              5123.0
# CODE                      28237113                    NaN                 NaN
# DISTRICT                       NaN                    NaN                 NaN
# SCHOOL                         NaN                    NaN                 NaN
# T1                             NaN                    NaN                 NaN
# T2                             NaN                    NaN                 NaN
# T3                             NaN                    NaN                 NaN
# T4                             NaN                    NaN                 NaN
# T5                             NaN                    NaN                 NaN
# T6                             NaN                    NaN                 NaN
# T7                             NaN                    NaN                 NaN
# SUM                           16.0                    NaN                 NaN
# PERCENTAGE                    16.0                    8.0                17.6
# REGIONAL_STATUS           Участник               Участник              Призер
# AUTHENTIC                      оба                процент             процент
# COMMENT                        NaN                    NaN                 NaN
#
#                                    6013          2914                   7840   \
# SUBJECT                     русский язык  русский язык           русский язык
# YEAR                                2022          2022                   2022
# REGION                Московская область        Москва  Ленинградская область
# DATA_AVAILABLE                      TRUE          TRUE                   TRUE
# WINNERS_ONLY                       False         False                  False
# GRADE_OF_COMPETITION                10.0          11.0                   10.0
# ID                                6012.0        2913.0                 7839.0
# CODE                                 NaN      28236142                    NaN
# DISTRICT                             NaN           NaN             Тихвинский
# SCHOOL                               NaN           NaN                    NaN
# T1                                   NaN           NaN                    1.5
# T2                                   NaN           NaN                    0.0
# T3                                   NaN           NaN                    0.0
# T4                                   NaN           NaN                    0.5
# T5                                   NaN           NaN                    1.0
# T6                                   NaN           NaN                    0.0
# T7                                   NaN           NaN                    1.0
# SUM                                  NaN           1.0                    4.0
# PERCENTAGE                           6.0          0.89                    4.0
# REGIONAL_STATUS                 Участник      Участник               Участник
# AUTHENTIC                        процент           оба                    оба
# COMMENT                              NaN           NaN                    NaN
#
#                                    5126                   987    \
# SUBJECT                     русский язык           русский язык
# YEAR                                2022                   2022
# REGION                Московская область  Волгоградская область
# DATA_AVAILABLE                      TRUE                   TRUE
# WINNERS_ONLY                       False                  False
# GRADE_OF_COMPETITION                 9.0                   11.0
# ID                                5125.0                  986.0
# CODE                                 NaN                    NaN
# DISTRICT                             NaN                    NaN
# SCHOOL                               NaN                    NaN
# T1                                   NaN                    NaN
# T2                                   NaN                    NaN
# T3                                   NaN                    NaN
# T4                                   NaN                    NaN
# T5                                   NaN                    NaN
# T6                                   NaN                    NaN
# T7                                   NaN                    NaN
# SUM                                  NaN                    NaN
# PERCENTAGE                          17.6               1.785714
# REGIONAL_STATUS                   Призер               Участник
# AUTHENTIC                        процент                процент
# COMMENT                              NaN                    NaN
#
#                                    6422          3991          2107   \
# SUBJECT                     русский язык  русский язык  русский язык
# YEAR                                2022          2022          2022
# REGION                Московская область        Москва        Москва
# DATA_AVAILABLE                      TRUE          TRUE          TRUE
# WINNERS_ONLY                       False         False         False
# GRADE_OF_COMPETITION                11.0           9.0          11.0
# ID                                6421.0        3990.0        2106.0
# CODE                                 NaN      28238395      28236175
# DISTRICT                             NaN           NaN           NaN
# SCHOOL                               NaN           NaN           NaN
# T1                                   NaN           NaN           NaN
# T2                                   NaN           NaN           NaN
# T3                                   NaN           NaN           NaN
# T4                                   NaN           NaN           NaN
# T5                                   NaN           NaN           NaN
# T6                                   NaN           NaN           NaN
# T7                                   NaN           NaN           NaN
# SUM                                  NaN          51.5          67.0
# PERCENTAGE                          12.9         58.52         59.82
# REGIONAL_STATUS                 Участник    Победитель        Призер
# AUTHENTIC                        процент           оба           оба
# COMMENT                              NaN           NaN           NaN
#
#                                   9409                10191  \
# SUBJECT                    русский язык        русский язык
# YEAR                               2022                2022
# REGION                Самарская область  Смоленская область
# DATA_AVAILABLE                     TRUE                TRUE
# WINNERS_ONLY                      False               False
# GRADE_OF_COMPETITION                9.0                11.0
# ID                               9407.0             10187.0
# CODE                                NaN                 NaN
# DISTRICT                      г. Самара     Вяземский район
# SCHOOL                              NaN                 NaN
# T1                                  NaN                 3.0
# T2                                  NaN                 0.0
# T3                                  NaN                 5.0
# T4                                  NaN                 2.0
# T5                                  NaN                 5.0
# T6                                  NaN                 3.5
# T7                                  NaN                 2.0
# SUM                                 NaN                20.5
# PERCENTAGE                          9.6                18.3
# REGIONAL_STATUS                Участник            Участник
# AUTHENTIC                       процент                 оба
# COMMENT                             NaN                 NaN
#
#                                         7668                6029   \
# SUBJECT                          русский язык        русский язык
# YEAR                                     2022                2022
# REGION                     Курганская область  Московская область
# DATA_AVAILABLE                           TRUE                TRUE
# WINNERS_ONLY                            False               False
# GRADE_OF_COMPETITION                      9.0                10.0
# ID                                     7667.0              6028.0
# CODE                                      NaN                 NaN
# DISTRICT                                  NaN                 NaN
# SCHOOL                МКОУ СОШ №40 г. Кургана                 NaN
# T1                                        NaN                 NaN
# T2                                        NaN                 NaN
# T3                                        NaN                 NaN
# T4                                        NaN                 NaN
# T5                                        NaN                 NaN
# T6                                        NaN                 NaN
# T7                                        NaN                 NaN
# SUM                                       NaN                 NaN
# PERCENTAGE                               11.3                 5.5
# REGIONAL_STATUS                      Участник            Участник
# AUTHENTIC                             процент             процент
# COMMENT                                   NaN                 NaN
#
#                              1271                10669
# SUBJECT               русский язык        русский язык
# YEAR                          2022                2022
# REGION                    Дагестан     Томская область
# DATA_AVAILABLE                TRUE                TRUE
# WINNERS_ONLY                 False               False
# GRADE_OF_COMPETITION          11.0                11.0
# ID                          1270.0             10665.0
# CODE                           NaN                 NaN
# DISTRICT                  Хасавюрт  Каргасокский район
# SCHOOL                         NaN                 NaN
# T1                             NaN                 NaN
# T2                             NaN                 NaN
# T3                             NaN                 NaN
# T4                             NaN                 NaN
# T5                             NaN                 NaN
# T6                             NaN                 NaN
# T7                             NaN                 NaN
# SUM                           43.5                20.0
# PERCENTAGE                    38.8                17.9
# REGIONAL_STATUS             Призер            Участник
# AUTHENTIC                      оба                 оба
# COMMENT                        NaN                 NaN

# %% [markdown]
# ### Итог
# #### Проанализировав 1 этап (Предобработка данных) мы видим что было много аномальных значений которые мы постарались исправить и убрать, было много пустых значений, которые мы заполнили данными, а те что неподдаются обработке и заполнению, удалили. Пройдя этот этап мы подготовили данные для последующего взаимодействия
